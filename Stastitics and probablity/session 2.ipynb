# %% [markdown]
# session 2

# %% [markdown]
# task1

# %% [markdown]
# Given the following columns from a mock Zomato restaurant dataset — Restaurant Name, Cuisine Type, Average Cost for Two, User Rating, City, and Open/Closed Status — classify each column as either Numerical (Continuous or Discrete) or Categorical (Nominal or Ordinal)

# %%
'''
Column	               Data Type	   Sub-type  	     Reason
Restaurant Name        Categorical	  Nominal            Names are labels and have no natural order.
Cuisine Type	       Categorical	  Nominal	         Examples: Indian, Chinese, Italian; there is no ranking.
Average Cost for Two   Numerical	Continuous	         Cost is a measurable quantity and can have decimal values.
User Rating	           Numerical	Continuous	         Rating represents a numerical measurement, e.g. 3.5 or 4.2.
City	               Categorical	 Nominal	         Cities are labels with no natural ranking.
Open/Closed Status	   Categorical    Nominal	         Open and Closed are categories without an order.
'''

# %% [markdown]
# task 2
#
# Create a table with 8 real-life examples (not from class) of data you might find in popular apps like Instagram, Flipkart, or IRCTC. For each, specify the measurement scale (Nominal, Ordinal, Interval, or Ratio) and briefly explain your choice.<br><br><em><strong>Hint:</strong> Think about things like 'Order Status', 'Train Departure Time', 'Number of Likes', or 'Payment Method'.</em>

# %%
'''
Example          	App	         Measurement Scale	        Explanation

Payment Method   	Flipkart	   Nominal	               UPI, Cash, Card, and Net Banking are categories with no order.
Order Status    	Flipkart	  Ordinal	               Status can represent an ordered process such as Ordered → Shipped → Delivered.
Number of Likes  	Instagram	   Ratio	               Likes have a true zero, and 20 likes is twice 10 likes.
Product Price    	Flipkart	   Ratio	              ₹0 represents no price/value, and ratios are meaningful.
Train Departure Time IRCTC	     Interval	              Time of day has meaningful differences, but 00:00 does not represent an absolute zero.
Passenger Age	     IRCTC	       Ratio	              Age has a meaningful zero and ratios can be compared.
Product Category	Flipkart	Nominal	                 Electronics, Clothing, Books, etc. are categories without ranking.
Customer Rating   	Flipkart 	Ordinal	                 1-star to 5-star ratings have a meaningful order, but the difference between ratings isn't necessarily equal.
'''

# %% [markdown]
# task 3
#
# Given this time-series data from a Spotify user's listening history — Date, Song Name, Play Count per Day — identify which columns represent time-series, and which are categorical or numerical. Explain your reasoning.

# %%
'''
Column          	Classification	            Reason

Date            	Time-series / Temporal	    It records observations according to time.
Song Name       	Categorical – Nominal	    Song names are labels and have no natural order.
Play Count per Day	Numerical   – Discrete	    It counts how many times a song was played, so values are normally whole numbers.
'''

# %% [markdown]
# task 4
# Write a function or pseudocode that takes a column of data (array of values) from a Flipkart order history and automatically detects whether it is likely Nominal, Ordinal, Interval, or Ratio scale. Briefly describe the logic used for each type.<br><br><em><strong>Constraint:</strong> You do not need to write a perfect algorithm — focus on simple rules based on value types and patterns.</em>

# %%
FUNCTION detect_scale(column):

    IF column contains dates or time values:
        RETURN "Interval"

    ELSE IF column contains text/categories:

        IF categories have a natural order:
            RETURN "Ordinal"
        ELSE:
            RETURN "Nominal"

    ELSE IF column contains numerical values:

        IF values represent counts, money, age, quantity,
           distance, weight, etc.:
            RETURN "Ratio"

        ELSE:
            RETURN "Interval"

    ELSE:
        RETURN "Unknown"
