# %%
#task 1 - create a python script file named analytics_intro.ipynb and write a cell that print your name and your favorite app using the print() function 
print("Hello")
print("My name is Sagar")
print("My favorite app is - Google ")
# Out:
# Hello
# My name is Sagar
# My favorite app is - Google

# %%
# task 3 - create a python code to print the current year using datetime modules 

import datetime

current_year = datetime.datetime.now().year

print("Current Year:", current_year)
# Out:
# Current Year: 2026
